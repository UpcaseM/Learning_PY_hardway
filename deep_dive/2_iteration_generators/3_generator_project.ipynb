# %% [markdown]
# For this project you are given a file that contains some parking ticket violations for NYC.
#
# (It's just a tiny extract!)
#
# If you're wondering where I get these data sets, Kaggle is an **excellent** source of data sets in a whole variety of topics:
# https://www.kaggle.com/
#
# You have to sign up, but it's free.
#
# If you want the full data set, it's available here: https://www.kaggle.com/new-york-city/nyc-parking-tickets/version/2#

# %%
data = '/mnt/data-ubuntu/Projects/Learning_PY_hardway/data/deep_dive/nyc_parking_tickets_extract.csv'

# %% [markdown]
# ## Goal 1
# Create a lazy iterator that will return a named tuple of the data in each row. The data types should be appropriate - i.e. if the column is a date, you should be storing dates in the named tuple, if the field is an integer, then it should be stored as an integer, etc.

# %%
class Tickets:
    from collections import namedtuple
    from datetime import datetime
    Ticket = namedtuple('Ticket', 
                        '''
                        summond_num, 
                        plate_id,
                        reg_state,
                        plate_type,
                        issue_date,
                        violation_code,
                        vehicle_body_type,
                        maker,
                        violation_descr
                        ''')
    
    def __init__(self, data):
        self.data = data
        
    def __iter__(self):
        return Tickets.ticket(self.data)
    
    @staticmethod
    def ticket(data):
        with open(data) as f:
            next(f)
            for row in f:
                lst_t = row.split(',')
                t = Tickets.Ticket(int(lst_t[0]),
                                   str(lst_t[1]),
                                   str(lst_t[2]),
                                   str(lst_t[3]),
                                   datetime.strptime(lst_t[4], '%m/%d/%Y').date(),
                                   int(lst_t[5]),
                                   str(lst_t[6]),
                                   str(lst_t[7]),
                                   str(lst_t[8].strip())
                                  )
                yield t

# %%
tickets = Tickets(data)

# %%
for t in tickets:
    print(t)
# Out:
# Ticket(summond_num=4006478550, plate_id='VAD7274', reg_state='VA', plate_type='PAS', issue_date=datetime.date(2016, 10, 5), violation_code=5, vehicle_body_type='4D', maker='BMW', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4006462396, plate_id='22834JK', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 30), violation_code=5, vehicle_body_type='VAN', maker='CHEVR', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4007117810, plate_id='21791MG', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 10), violation_code=5, vehicle_body_type='VAN', maker='DODGE', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4006265037, plate_id='FZX9232', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 23), violation_code=5, vehicle_body_type='SUBN', maker='FORD', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4006535600, plate_id='N203399C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 10, 19), violation_code=5, vehicle_body_type='SUBN', maker='FORD', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4007156700, plate_id='92163MG', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 13), violation_code=5, vehicle_body_type='VAN', maker='FRUEH', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4006687989, plate_id='MIQ600', reg_state='SC', plate_type='PAS', issue_date=datetime.date(2016, 11, 21), violation_code=5, vehicle_body_type='VN', maker='HONDA', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4006943052, plate_id='2AE3984', reg_state='MD', plate_type='PAS', issue_date=datetime.date(2017, 2, 1), violation_code=5, vehicle_body_type='SW', maker='LINCO', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4007306795, plate_id='HLG4926', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 30), violation_code=5, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=4007124590, plate_id='T715907C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 4, 3), violation_code=5, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='BUS LANE VIOLATION')
# Ticket(summond_num=5096061966, plate_id='HRC9475', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 18), violation_code=7, vehicle_body_type='SUBN', maker='CADIL', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094070400, plate_id='DYP8042', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 26), violation_code=7, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094906770, plate_id='G30ESY', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 1, 1), violation_code=7, vehicle_body_type='WAGO', maker='CHRYS', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093319363, plate_id='GGT8868', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 6), violation_code=7, vehicle_body_type='SUBN', maker='CHRYS', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092638849, plate_id='107DDD', reg_state='NY', plate_type='SPO', issue_date=datetime.date(2016, 7, 20), violation_code=7, vehicle_body_type='SUBN', maker='DODGE', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093455337, plate_id='ENQT55', reg_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 9, 12), violation_code=7, vehicle_body_type='VN', maker='DODGE', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094961366, plate_id='GSU4156', reg_state='OH', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=7, vehicle_body_type='4S', maker='DODGE', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092906534, plate_id='V84FXV', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 8, 7), violation_code=7, vehicle_body_type='WAGO', maker='FIR', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093620865, plate_id='AD80228', reg_state='AZ', plate_type='PAS', issue_date=datetime.date(2016, 9, 24), violation_code=7, vehicle_body_type='TK', maker='FORD', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092733548, plate_id='EVX4041', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 26), violation_code=7, vehicle_body_type='SUBN', maker='FORD', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5095995530, plate_id='EMK5934', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 13), violation_code=7, vehicle_body_type='VAN', maker='GMC', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092750364, plate_id='DPH8955', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 27), violation_code=7, vehicle_body_type='SUBN', maker='HONDA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094658001, plate_id='GCF1897', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 10), violation_code=7, vehicle_body_type='4DSD', maker='HONDA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092833786, plate_id='HCS9434', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 3), violation_code=7, vehicle_body_type='SUBN', maker='HONDA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5096484040, plate_id='HHS1641', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 17), violation_code=7, vehicle_body_type='SUBN', maker='HONDA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5095797586, plate_id='KHE1889', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 3, 28), violation_code=7, vehicle_body_type='SDN', maker='HONDA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5095799807, plate_id='VES2440', reg_state='VA', plate_type='PAS', issue_date=datetime.date(2017, 3, 29), violation_code=7, vehicle_body_type='VAN', maker='HONDA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093533919, plate_id='CYU4598', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 16), violation_code=7, vehicle_body_type='SUBN', maker='HYUND', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093399735, plate_id='DZGT24', reg_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 9, 4), violation_code=7, vehicle_body_type='UT', maker='HYUND', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094058873, plate_id='GRN3101', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 29), violation_code=7, vehicle_body_type='4DSD', maker='HYUND', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094770986, plate_id='T668962C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 12, 19), violation_code=7, vehicle_body_type='4DSD', maker='HYUND', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093895611, plate_id='GVZ1407', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 14), violation_code=7, vehicle_body_type='4DSD', maker='JAGUA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094185792, plate_id='AGM9013', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 4), violation_code=7, vehicle_body_type='SUBN', maker='JEEP', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092708219, plate_id='F47DZF', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 7, 24), violation_code=7, vehicle_body_type='4 DR', maker='JEEP', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094759954, plate_id='GLB8157', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 19), violation_code=7, vehicle_body_type='SUBN', maker='JEEP', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093891046, plate_id='FJS4033', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 14), violation_code=7, vehicle_body_type='4DSD', maker='LEXUS', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093527853, plate_id='GYM9809', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 21), violation_code=7, vehicle_body_type='4DSD', maker='LEXUS', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5096683886, plate_id='HCS4873', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 18), violation_code=7, vehicle_body_type='4DSD', maker='LEXUS', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5096917368, plate_id='FZD8593', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 13), violation_code=7, vehicle_body_type='SUBN', maker='ME/BE', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094893737, plate_id='GER1584', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 31), violation_code=7, vehicle_body_type='4DSD', maker='ME/BE', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5096249300, plate_id='HEM8411', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 1), violation_code=7, vehicle_body_type='4DSD', maker='ME/BE', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5096958772, plate_id='165TRX', reg_state='CT', plate_type='PAS', issue_date=datetime.date(2017, 6, 16), violation_code=7, vehicle_body_type='4W', maker='MERCU', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093703217, plate_id='HFG4313', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 30), violation_code=7, vehicle_body_type='4DSD', maker='MITSU', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094670736, plate_id='AXU4790', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 11), violation_code=7, vehicle_body_type='4DSD', maker='NISSA', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5094094166, plate_id='CZM4111', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 28), violation_code=7, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5096723768, plate_id='EDN2797', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 2), violation_code=7, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5093209120, plate_id='FZT5005', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 28), violation_code=7, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092469481, plate_id='GZH7067', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 10), violation_code=7, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5092451658, plate_id='GZH7067', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 8), violation_code=7, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=5095356545, plate_id='GZM8254', reg_state='NY', plate_type='OMS', issue_date=datetime.date(2017, 2, 18), violation_code=7, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='FAILURE TO STOP AT RED LIGHT')
# Ticket(summond_num=8410006650, plate_id='D53AUUN', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 21), violation_code=9, vehicle_body_type='4DSD', maker='LEXUS', violation_descr='09-Blocking the Box')
# Ticket(summond_num=8534116519, plate_id='CES6482', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 12), violation_code=9, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='09-Blocking the Box')
# Ticket(summond_num=8485674984, plate_id='T713160C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 6, 13), violation_code=9, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='09-Blocking the Box')
# Ticket(summond_num=8556557405, plate_id='59622JW', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 9), violation_code=10, vehicle_body_type='VAN', maker='FORD', violation_descr='10-No Stopping')
# Ticket(summond_num=8071038416, plate_id='AM479F', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 7, 7), violation_code=10, vehicle_body_type='DELV', maker='FRUEH', violation_descr='10-No Stopping')
# Ticket(summond_num=8483087236, plate_id='76822MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 19), violation_code=10, vehicle_body_type='DELV', maker='HIN', violation_descr='10-No Stopping')
# Ticket(summond_num=8481125088, plate_id='55179ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 10), violation_code=10, vehicle_body_type='DELV', maker='NS/OT', violation_descr='10-No Stopping')
# Ticket(summond_num=8506822300, plate_id='55106MB', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 31), violation_code=10, vehicle_body_type='VAN', maker='WORKH', violation_descr='10-No Stopping')
# Ticket(summond_num=8482331425, plate_id='86609MB', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 18), violation_code=13, vehicle_body_type='VAN', maker='CHEVR', violation_descr='13-No Stand (taxi stand)')
# Ticket(summond_num=8028246722, plate_id='T703619C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 9, 15), violation_code=13, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='13-No Stand (taxi stand)')
# Ticket(summond_num=8378547530, plate_id='FWZ8815', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 11), violation_code=14, vehicle_body_type='2DSD', maker='ACURA', violation_descr='14-No Standing')
# Ticket(summond_num=8489750210, plate_id='6DQT356', reg_state='CA', plate_type='PAS', issue_date=datetime.date(2016, 11, 28), violation_code=14, vehicle_body_type='4DSD', maker='AUDI', violation_descr='14-No Standing')
# Ticket(summond_num=1410726095, plate_id='DEP4792', reg_state='NC', plate_type='PAS', issue_date=datetime.date(2016, 7, 15), violation_code=14, vehicle_body_type='', maker='BMW', violation_descr='')
# Ticket(summond_num=8421031235, plate_id='GGA4266', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 18), violation_code=14, vehicle_body_type='4DSD', maker='BMW', violation_descr='14-No Standing')
# Ticket(summond_num=7730553259, plate_id='DLZ8901', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 26), violation_code=14, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='14-No Standing')
# Ticket(summond_num=8498520046, plate_id='HKF6916', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 27), violation_code=14, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='14-No Standing')
# Ticket(summond_num=8537807813, plate_id='HNF6718', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 21), violation_code=14, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='14-No Standing')
# Ticket(summond_num=8083571465, plate_id='KCG9559', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2016, 12, 22), violation_code=14, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='14-No Standing')
# Ticket(summond_num=7536689184, plate_id='ZCL5723', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 1, 26), violation_code=14, vehicle_body_type='VAN', maker='CHEVR', violation_descr='14-No Standing')
# Ticket(summond_num=8480505680, plate_id='HCT2134', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 18), violation_code=14, vehicle_body_type='SUBN', maker='CHRYS', violation_descr='14-No Standing')
# Ticket(summond_num=8481973580, plate_id='28693MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 13), violation_code=14, vehicle_body_type='VAN', maker='DODGE', violation_descr='14-No Standing')
# Ticket(summond_num=8460500214, plate_id='30408MC', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 8, 4), violation_code=14, vehicle_body_type='PICK', maker='DODGE', violation_descr='14-No Standing')
# Ticket(summond_num=8482817036, plate_id='50501JT', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 11), violation_code=14, vehicle_body_type='VAN', maker='DODGE', violation_descr='14-No Standing')
# Ticket(summond_num=8117027999, plate_id='83317ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 27), violation_code=14, vehicle_body_type='VAN', maker='DODGE', violation_descr='14-No Standing')
# Ticket(summond_num=8488121532, plate_id='FLX2674', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 5), violation_code=14, vehicle_body_type='2DSD', maker='DODGE', violation_descr='14-No Standing')
# Ticket(summond_num=8543952980, plate_id='FSZ8671', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 21), violation_code=14, vehicle_body_type='SUBN', maker='DODGE', violation_descr='14-No Standing')
# Ticket(summond_num=8501806912, plate_id='KGP1166', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 6, 4), violation_code=14, vehicle_body_type='VAN', maker='DODGE', violation_descr='14-No Standing')
# Ticket(summond_num=8107542976, plate_id='11AH74', reg_state='MA', plate_type='PAS', issue_date=datetime.date(2017, 1, 29), violation_code=14, vehicle_body_type='4DSD', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8564650320, plate_id='29222MK', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 5), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8010367576, plate_id='30661MA', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 12, 22), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8505159536, plate_id='41795JX', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 3, 9), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=7813887440, plate_id='44267JZ', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 8, 12), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8440509546, plate_id='49317JX', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 29), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=1408575656, plate_id='6XWZ969', reg_state='CA', plate_type='PAS', issue_date=datetime.date(2016, 7, 6), violation_code=14, vehicle_body_type='SDN', maker='FORD', violation_descr='')
# Ticket(summond_num=8516853275, plate_id='72100MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 12), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=7059924103, plate_id='91878MB', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 12), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8170085561, plate_id='ENM3708', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 10), violation_code=14, vehicle_body_type='SUBN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8527511113, plate_id='F70GEP', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 1), violation_code=14, vehicle_body_type='SUBN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8511453696, plate_id='FSY6987', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 13), violation_code=14, vehicle_body_type='SUBN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=1413745933, plate_id='HCC2829', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 22), violation_code=14, vehicle_body_type='VAN', maker='FORD', violation_descr='')
# Ticket(summond_num=8484882226, plate_id='S25DSK', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 6, 8), violation_code=14, vehicle_body_type='PICK', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=8524054499, plate_id='ZRK24R', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 3, 18), violation_code=14, vehicle_body_type='SUBN', maker='FORD', violation_descr='14-No Standing')
# Ticket(summond_num=1423945281, plate_id='2240653', reg_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 5, 13), violation_code=14, vehicle_body_type='', maker='FRUEH', violation_descr='')
# Ticket(summond_num=8577650820, plate_id='10632JU', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 20), violation_code=14, vehicle_body_type='UTIL', maker='FRUEH', violation_descr='14-No Standing')
# Ticket(summond_num=7056662882, plate_id='83038ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 21), violation_code=14, vehicle_body_type='VAN', maker='FRUEH', violation_descr='14-No Standing')
# Ticket(summond_num=8324025510, plate_id='83146ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 27), violation_code=14, vehicle_body_type='VAN', maker='FRUEH', violation_descr='14-No Standing')
# Ticket(summond_num=8286541110, plate_id='85846MD', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 25), violation_code=14, vehicle_body_type='VAN', maker='FRUEH', violation_descr='14-No Standing')
# Ticket(summond_num=8270548250, plate_id='91028MJ', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 12, 13), violation_code=14, vehicle_body_type='DELV', maker='FRUEH', violation_descr='14-No Standing')
# Ticket(summond_num=8480520395, plate_id='99886MC', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 19), violation_code=14, vehicle_body_type='VAN', maker='FRUEH', violation_descr='14-No Standing')
# Ticket(summond_num=8496410791, plate_id='AP338E', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 17), violation_code=14, vehicle_body_type='TRAC', maker='FRUEH', violation_descr='14-No Standing')
# Ticket(summond_num=8530950458, plate_id='HAY5880', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 8), violation_code=14, vehicle_body_type='SUBN', maker='GMC', violation_descr='14-No Standing')
# Ticket(summond_num=8552003569, plate_id='XJ275S', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 25), violation_code=14, vehicle_body_type='PICK', maker='GMC', violation_descr='14-No Standing')
# Ticket(summond_num=8536010903, plate_id='25472MG', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 16), violation_code=14, vehicle_body_type='REFG', maker='HIN', violation_descr='14-No Standing')
# Ticket(summond_num=8508953549, plate_id='XDLS80', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 2, 1), violation_code=14, vehicle_body_type='DELV', maker='HIN', violation_descr='14-No Standing')
# Ticket(summond_num=7191990831, plate_id='AA00234', reg_state='CT', plate_type='PAS', issue_date=datetime.date(2016, 7, 2), violation_code=14, vehicle_body_type='SUBN', maker='HONDA', violation_descr='14-No Standing')
# Ticket(summond_num=8519503676, plate_id='FCX7311', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 20), violation_code=14, vehicle_body_type='SUBN', maker='HONDA', violation_descr='14-No Standing')
# Ticket(summond_num=1418739704, plate_id='GJK5307', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 9), violation_code=14, vehicle_body_type='SDN', maker='HONDA', violation_descr='')
# Ticket(summond_num=7994359840, plate_id='GNG1097', reg_state='TX', plate_type='PAS', issue_date=datetime.date(2016, 7, 15), violation_code=14, vehicle_body_type='SUBN', maker='HONDA', violation_descr='14-No Standing')
# Ticket(summond_num=1414856374, plate_id='HLE9929', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 13), violation_code=14, vehicle_body_type='SUBN', maker='HONDA', violation_descr='')
# Ticket(summond_num=8474909971, plate_id='S938464', reg_state='IA', plate_type='PAS', issue_date=datetime.date(2017, 1, 9), violation_code=14, vehicle_body_type='SUBN', maker='HONDA', violation_descr='14-No Standing')
# Ticket(summond_num=1416903379, plate_id='CRM6911', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 16), violation_code=14, vehicle_body_type='SDN', maker='HYUND', violation_descr='')
# Ticket(summond_num=8340512559, plate_id='CZB9676', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 23), violation_code=14, vehicle_body_type='2DSD', maker='HYUND', violation_descr='14-No Standing')
# Ticket(summond_num=8497566683, plate_id='17596JE', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 16), violation_code=14, vehicle_body_type='DELV', maker='INTER', violation_descr='14-No Standing')
# Ticket(summond_num=8517821075, plate_id='32295MA', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 27), violation_code=14, vehicle_body_type='DELV', maker='INTER', violation_descr='14-No Standing')
# Ticket(summond_num=1418035762, plate_id='62935JM', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 24), violation_code=14, vehicle_body_type='DELV', maker='INTER', violation_descr='')
# Ticket(summond_num=8482055392, plate_id='92638JU', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 25), violation_code=14, vehicle_body_type='VAN', maker='INTER', violation_descr='14-No Standing')
# Ticket(summond_num=8506706490, plate_id='AP166T', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 2, 20), violation_code=14, vehicle_body_type='DELV', maker='INTER', violation_descr='14-No Standing')
# Ticket(summond_num=8473761297, plate_id='33049MJ', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 1), violation_code=14, vehicle_body_type='DELV', maker='ISUZU', violation_descr='14-No Standing')
# Ticket(summond_num=8484877693, plate_id='XBYG52', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 12), violation_code=14, vehicle_body_type='VAN', maker='ISUZU', violation_descr='14-No Standing')
# Ticket(summond_num=8152046917, plate_id='VFW9441', reg_state='VA', plate_type='PAS', issue_date=datetime.date(2016, 8, 14), violation_code=14, vehicle_body_type='SUBN', maker='JEEP', violation_descr='14-No Standing')
# Ticket(summond_num=8503265503, plate_id='23800TC', reg_state='NY', plate_type='TRC', issue_date=datetime.date(2017, 3, 28), violation_code=14, vehicle_body_type='TRAC', maker='KENWO', violation_descr='14-No Standing')
# Ticket(summond_num=8489721312, plate_id='49734MA', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 4), violation_code=14, vehicle_body_type='DELV', maker='KENWO', violation_descr='14-No Standing')
# Ticket(summond_num=8464532088, plate_id='HJR5750', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 3), violation_code=14, vehicle_body_type='SUBN', maker='KIA', violation_descr='14-No Standing')
# Ticket(summond_num=8488825948, plate_id='HAU1278', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 31), violation_code=14, vehicle_body_type='SUBN', maker='LEXUS', violation_descr='14-No Standing')
# Ticket(summond_num=8559362496, plate_id='HLW7798', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 13), violation_code=14, vehicle_body_type='4DSD', maker='LEXUS', violation_descr='14-No Standing')
# Ticket(summond_num=8478353860, plate_id='VUE95C', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 12, 6), violation_code=14, vehicle_body_type='4DSD', maker='LEXUS', violation_descr='14-No Standing')
# Ticket(summond_num=8518911631, plate_id='ZD53LE', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 17), violation_code=14, vehicle_body_type='SUBN', maker='LEXUS', violation_descr='14-No Standing')
# Ticket(summond_num=1416091415, plate_id='75213MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 11, 28), violation_code=14, vehicle_body_type='VAN', maker='ME/BE', violation_descr='')
# Ticket(summond_num=8482374059, plate_id='F96FBF', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 23), violation_code=14, vehicle_body_type='4DSD', maker='ME/BE', violation_descr='14-No Standing')
# Ticket(summond_num=8544960947, plate_id='HMX8950', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 27), violation_code=14, vehicle_body_type='4DSD', maker='ME/BE', violation_descr='14-No Standing')
# Ticket(summond_num=1418609274, plate_id='8P82H', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 12, 21), violation_code=14, vehicle_body_type='TAXI', maker='NISSA', violation_descr='')
# Ticket(summond_num=1417565895, plate_id='HEB8184', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 11), violation_code=14, vehicle_body_type='SDN', maker='NISSA', violation_descr='')
# Ticket(summond_num=8155550278, plate_id='W56GSE', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 22), violation_code=14, vehicle_body_type='4DSD', maker='NISSA', violation_descr='14-No Standing')
# Ticket(summond_num=7433187960, plate_id='2330830', reg_state='ME', plate_type='PAS', issue_date=datetime.date(2017, 3, 6), violation_code=14, vehicle_body_type='TRLR', maker='NS/OT', violation_descr='14-No Standing')
# Ticket(summond_num=7645052715, plate_id='FRZ3573', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=14, vehicle_body_type='SUBN', maker='NS/OT', violation_descr='14-No Standing')
# Ticket(summond_num=7922559173, plate_id='XCYU94', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 24), violation_code=14, vehicle_body_type='VAN', maker='NS/OT', violation_descr='14-No Standing')
# Ticket(summond_num=7767415582, plate_id='XW915N', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 3, 29), violation_code=14, vehicle_body_type='DELV', maker='NS/OT', violation_descr='14-No Standing')
# Ticket(summond_num=8524350581, plate_id='HGR5953', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 27), violation_code=14, vehicle_body_type='4DSD', maker='OLDSM', violation_descr='14-No Standing')
# Ticket(summond_num=7499844705, plate_id='GGT7948', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 22), violation_code=14, vehicle_body_type='SUBN', maker='SUBAR', violation_descr='14-No Standing')
# Ticket(summond_num=7150327266, plate_id='HWE6388', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2016, 8, 5), violation_code=14, vehicle_body_type='SUBN', maker='SUBAR', violation_descr='14-No Standing')
# Ticket(summond_num=8537603818, plate_id='ASG8770', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 26), violation_code=14, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='14-No Standing')
# Ticket(summond_num=8210533952, plate_id='GST8679', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 21), violation_code=14, vehicle_body_type='2DSD', maker='TOYOT', violation_descr='14-No Standing')
# Ticket(summond_num=8555462198, plate_id='HKT4222', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 12), violation_code=14, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='14-No Standing')
# Ticket(summond_num=1404838156, plate_id='R57AAE', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 29), violation_code=14, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='')
# Ticket(summond_num=8527806162, plate_id='T659832C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 6, 4), violation_code=14, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='14-No Standing')
# Ticket(summond_num=8513520615, plate_id='77026MG', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 31), violation_code=14, vehicle_body_type='TRAC', maker='VOLVO', violation_descr='14-No Standing')
# Ticket(summond_num=8251031485, plate_id='HJP5565', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 4), violation_code=16, vehicle_body_type='4DSD', maker='CHEVR', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=7813745231, plate_id='GEL1890', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 19), violation_code=16, vehicle_body_type='SUBN', maker='CHRYS', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=8444534183, plate_id='36598MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 11, 23), violation_code=16, vehicle_body_type='VAN', maker='DODGE', violation_descr='16-No Std (Com Veh) Com Plate')
# Ticket(summond_num=8061037749, plate_id='HFG7121', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 22), violation_code=16, vehicle_body_type='SUBN', maker='DODGE', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=8250539527, plate_id='24745ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 11, 9), violation_code=16, vehicle_body_type='VAN', maker='FORD', violation_descr='16-No Std (Com Veh) Com Plate')
# Ticket(summond_num=8308520170, plate_id='49033ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 7, 14), violation_code=16, vehicle_body_type='VAN', maker='FORD', violation_descr='16-No Std (Com Veh) Com Plate')
# Ticket(summond_num=8504915323, plate_id='57011ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 6), violation_code=16, vehicle_body_type='SUBN', maker='FORD', violation_descr='16-No Std (Com Veh) Com Plate')
# Ticket(summond_num=8339536023, plate_id='XCEG93', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 9, 15), violation_code=16, vehicle_body_type='VAN', maker='FORD', violation_descr='16-No Std (Com Veh) Com Plate')
# Ticket(summond_num=8566405183, plate_id='GJD5585', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 1), violation_code=16, vehicle_body_type='4DSD', maker='ME/BE', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=7051225662, plate_id='N61GZN', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 11, 25), violation_code=16, vehicle_body_type='SUBN', maker='SATUR', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=8149510126, plate_id='GTP8988', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 10), violation_code=16, vehicle_body_type='2DSD', maker='SMART', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=7052028463, plate_id='HGM9782', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 30), violation_code=16, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=8474913706, plate_id='T674455C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 2, 8), violation_code=16, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='16A-No Std (Com Veh) Non-COM')
# Ticket(summond_num=8506607206, plate_id='18752MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 3, 16), violation_code=17, vehicle_body_type='VAN', maker='CHEVR', violation_descr='17-No Stand (exc auth veh)')
# Ticket(summond_num=8438519763, plate_id='89882JV', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 13), violation_code=17, vehicle_body_type='VAN', maker='GMC', violation_descr='17-No Stand (exc auth veh)')
# Ticket(summond_num=8551111954, plate_id='GCE9214', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 25), violation_code=17, vehicle_body_type='4DSD', maker='HONDA', violation_descr='17-No Stand (exc auth veh)')
# Ticket(summond_num=8516654059, plate_id='AP169V', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 2, 22), violation_code=18, vehicle_body_type='DELV', maker='INTER', violation_descr='18-No Stand (bus lane)')
# Ticket(summond_num=1368119141, plate_id='BMLV150', reg_state='ON', plate_type='PAS', issue_date=datetime.date(2016, 7, 16), violation_code=19, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='')
# Ticket(summond_num=8528274184, plate_id='EKF9820', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 1), violation_code=19, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8522350073, plate_id='83290MD', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 24), violation_code=19, vehicle_body_type='SUBN', maker='DODGE', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8070097437, plate_id='T62GJP', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 9, 18), violation_code=19, vehicle_body_type='PICK', maker='DODGE', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8509409523, plate_id='35050JU', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 24), violation_code=19, vehicle_body_type='PICK', maker='FORD', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=1413553552, plate_id='41126BB', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 7, 28), violation_code=19, vehicle_body_type='VAN', maker='FORD', violation_descr='')
# Ticket(summond_num=8514220482, plate_id='2588073', reg_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 5, 29), violation_code=19, vehicle_body_type='DELV', maker='FRUEH', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8485652319, plate_id='0480PRA', reg_state='MN', plate_type='PAS', issue_date=datetime.date(2017, 1, 26), violation_code=19, vehicle_body_type='DELV', maker='FRUEH', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=7014671406, plate_id='B0951V', reg_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 9, 7), violation_code=19, vehicle_body_type='DELV', maker='FRUEH', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=1422732710, plate_id='GMK4592', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 19), violation_code=19, vehicle_body_type='SDN', maker='HONDA', violation_descr='')
# Ticket(summond_num=7249114220, plate_id='GPP7413', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 8), violation_code=19, vehicle_body_type='SUBN', maker='HONDA', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=7499990163, plate_id='HKT3209', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 13), violation_code=19, vehicle_body_type='SUBN', maker='HONDA', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8491667738, plate_id='JPC4516', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 3, 1), violation_code=19, vehicle_body_type='4DSD', maker='INFIN', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8302046280, plate_id='63444JM', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 26), violation_code=19, vehicle_body_type='VAN', maker='INTER', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8009901763, plate_id='13657MD', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 27), violation_code=19, vehicle_body_type='DELV', maker='KENWO', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=1424024420, plate_id='HPD1970', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 10), violation_code=19, vehicle_body_type='SDN', maker='KIA', violation_descr='')
# Ticket(summond_num=8511718990, plate_id='50104MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 9), violation_code=19, vehicle_body_type='VAN', maker='ME/BE', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=1415429522, plate_id='17236MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 3, 3), violation_code=19, vehicle_body_type='SUBN', maker='MITSU', violation_descr='')
# Ticket(summond_num=8476355312, plate_id='47829MD', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 14), violation_code=19, vehicle_body_type='DELV', maker='PETER', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=1406918726, plate_id='5M39B', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 7, 13), violation_code=19, vehicle_body_type='TAXI', maker='TOYOT', violation_descr='')
# Ticket(summond_num=7241990262, plate_id='DVA1919', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 16), violation_code=19, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8330511935, plate_id='HBY7509', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 30), violation_code=19, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=1423536058, plate_id='HCS2336', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 27), violation_code=19, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='')
# Ticket(summond_num=8519016595, plate_id='QU655', reg_state='RI', plate_type='PAS', issue_date=datetime.date(2017, 6, 12), violation_code=19, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=8530522310, plate_id='T640396C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 5, 27), violation_code=19, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='19-No Stand (bus stop)')
# Ticket(summond_num=1413358512, plate_id='54295PC', reg_state='NY', plate_type='APP', issue_date=datetime.date(2016, 8, 9), violation_code=19, vehicle_body_type='BUS', maker='', violation_descr='')
# Ticket(summond_num=8269048434, plate_id='CDPE57', reg_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 8, 21), violation_code=20, vehicle_body_type='4DSD', maker='ACURA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=7036998684, plate_id='VML8110', reg_state='VA', plate_type='PAS', issue_date=datetime.date(2017, 2, 21), violation_code=20, vehicle_body_type='4DSD', maker='BMW', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8515215408, plate_id='HFB1731', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 14), violation_code=20, vehicle_body_type='SUBN', maker='CADIL', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8470607042, plate_id='MYSUMMER', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 7, 27), violation_code=20, vehicle_body_type='SUBN', maker='CADIL', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=1371960501, plate_id='FEP2455', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 18), violation_code=20, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='')
# Ticket(summond_num=8550963045, plate_id='GSU8031', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 20), violation_code=20, vehicle_body_type='4DSD', maker='CHEVR', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8358531096, plate_id='FGN4109', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 14), violation_code=20, vehicle_body_type='SUBN', maker='CHRYS', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=7623299300, plate_id='530LAW', reg_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 7, 23), violation_code=20, vehicle_body_type='SUBN', maker='CITRO', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=1416638830, plate_id='GLP367', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 30), violation_code=20, vehicle_body_type='SUBN', maker='DODGE', violation_descr='')
# Ticket(summond_num=7441946736, plate_id='GMT8049', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 27), violation_code=20, vehicle_body_type='4DSD', maker='DODGE', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8522913341, plate_id='KHB4412', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 4, 17), violation_code=20, vehicle_body_type='4DSD', maker='DODGE', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8421057479, plate_id='64921JT', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 27), violation_code=20, vehicle_body_type='VAN', maker='FORD', violation_descr='20-No Parking (Com Plate)')
# Ticket(summond_num=8533873610, plate_id='HBZ9785', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 16), violation_code=20, vehicle_body_type='2DSD', maker='FORD', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8388024498, plate_id='HGF2284', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 14), violation_code=20, vehicle_body_type='SUBN', maker='FORD', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8086541423, plate_id='K78FFL', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 9, 7), violation_code=20, vehicle_body_type='SUBN', maker='FORD', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8521664060, plate_id='XW347T', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 6, 9), violation_code=20, vehicle_body_type='VAN', maker='FORD', violation_descr='20-No Parking (Com Plate)')
# Ticket(summond_num=7541979089, plate_id='GPW5892', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 16), violation_code=20, vehicle_body_type='SUBN', maker='GMC', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=7487986524, plate_id='AVS4503', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 16), violation_code=20, vehicle_body_type='PICK', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8141015345, plate_id='FRJ7858', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 22), violation_code=20, vehicle_body_type='SUBN', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8543009080, plate_id='GJA1784', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 2), violation_code=20, vehicle_body_type='SUBN', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8275023932, plate_id='GRR5700', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 16), violation_code=20, vehicle_body_type='2DSD', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8193526089, plate_id='GTE5903', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 8), violation_code=20, vehicle_body_type='4DSD', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=7809488399, plate_id='HBE5264', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 3), violation_code=20, vehicle_body_type='4DSD', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8241524547, plate_id='T715157C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 1, 19), violation_code=20, vehicle_body_type='SUBN', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=7578395609, plate_id='W81CNF', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 24), violation_code=20, vehicle_body_type='SUBN', maker='HONDA', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=8018756946, plate_id='7HG44', reg_state='AL', plate_type='PAS', issue_date=datetime.date(2016, 8, 29), violation_code=20, vehicle_body_type='4DSD', maker='HYUND', violation_descr='20A-No Parking (Non-COM)')
# Ticket(summond_num=7043255211, plate_id='HJC9828', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 10), violation_code=20, vehicle_body_type='4DSD', maker='HYUND', violation_descr='20A-No Parking (Non-COM)')
# ...
# Ticket(summond_num=8514728416, plate_id='GYP8889', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 28), violation_code=71, vehicle_body_type='SUBN', maker='FORD', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=7162362357, plate_id='GCE5560', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 5), violation_code=71, vehicle_body_type='2DSD', maker='HONDA', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8486910511, plate_id='GXC5916', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 13), violation_code=71, vehicle_body_type='4DSD', maker='HONDA', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=7959802142, plate_id='HAE6612', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 22), violation_code=71, vehicle_body_type='4DSD', maker='HONDA', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8474512311, plate_id='HLA6246', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 15), violation_code=71, vehicle_body_type='4DSD', maker='HONDA', violation_descr='71-Insp. Sticker Missing (NYS')
# Ticket(summond_num=1405823926, plate_id='GDV1998', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 1), violation_code=71, vehicle_body_type='SUBN', maker='HYUND', violation_descr='')
# Ticket(summond_num=8467031128, plate_id='R9D509', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 24), violation_code=71, vehicle_body_type='SUBN', maker='HYUND', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8378044166, plate_id='HJV2326', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 18), violation_code=71, vehicle_body_type='4DSD', maker='INFIN', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8535421774, plate_id='EGZ5296', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 21), violation_code=71, vehicle_body_type='SUBN', maker='JEEP', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8263642668, plate_id='HEA6308', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 16), violation_code=71, vehicle_body_type='SUBN', maker='JEEP', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=7067047705, plate_id='HFF1432', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 23), violation_code=71, vehicle_body_type='SUBN', maker='JEEP', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8168032202, plate_id='GZN5776', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 3), violation_code=71, vehicle_body_type='4DSD', maker='LEXUS', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8507861787, plate_id='HMY3697', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 10), violation_code=71, vehicle_body_type='SUBN', maker='LEXUS', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8297047957, plate_id='GUV7315', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 3), violation_code=71, vehicle_body_type='4DSD', maker='LINCO', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8472853342, plate_id='HJN6543', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 4), violation_code=71, vehicle_body_type='2DSD', maker='LINCO', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8524860388, plate_id='HGR2303', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 10), violation_code=71, vehicle_body_type='CONV', maker='ME/BE', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8561753377, plate_id='GWY8527', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 26), violation_code=71, vehicle_body_type='SUBN', maker='MERCU', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8544876754, plate_id='GBE4270', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 24), violation_code=71, vehicle_body_type='4DSD', maker='NISSA', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=7803960030, plate_id='HBU4265', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=71, vehicle_body_type='4DSD', maker='NISSA', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=7492597289, plate_id='HDF5609', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 19), violation_code=71, vehicle_body_type='4DSD', maker='NISSA', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8400523477, plate_id='HKT1200', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 28), violation_code=71, vehicle_body_type='4DSD', maker='NISSA', violation_descr='71-Insp. Sticker Missing (NYS')
# Ticket(summond_num=7646792536, plate_id='T686872C', reg_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 9, 14), violation_code=71, vehicle_body_type='4DSD', maker='NISSA', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8208026335, plate_id='DHW7141', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 5), violation_code=71, vehicle_body_type='2DSD', maker='NS/OT', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=7959796476, plate_id='GPY8489', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 6), violation_code=71, vehicle_body_type='SUBN', maker='ROVER', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8509455028, plate_id='34632BB', reg_state='NY', plate_type='OMR', issue_date=datetime.date(2017, 2, 12), violation_code=71, vehicle_body_type='BUS', maker='STAR', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8393022400, plate_id='HFP5696', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 16), violation_code=71, vehicle_body_type='SUBN', maker='SUBAR', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8525217207, plate_id='HGM9849', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 3), violation_code=71, vehicle_body_type='SUBN', maker='SUBAR', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8562558047, plate_id='CWP4893', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 1), violation_code=71, vehicle_body_type='SUBN', maker='TOYOT', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8236037095, plate_id='GMR8112', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 17), violation_code=71, vehicle_body_type='2DSD', maker='TOYOT', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8514463690, plate_id='GMZ9712', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 30), violation_code=71, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=8358550790, plate_id='HDY4158', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 18), violation_code=71, vehicle_body_type='4DSD', maker='TOYOT', violation_descr='71A-Insp Sticker Expired (NYS)')
# Ticket(summond_num=7959486440, plate_id='GYF2052', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 7), violation_code=71, vehicle_body_type='4DSD', maker='VOLKS', violation_descr='71-Insp. Sticker Missing (NYS')
# Ticket(summond_num=8300538318, plate_id='HFR6545', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 31), violation_code=71, vehicle_body_type='4DSD', maker='VOLVO', violation_descr='71-Insp. Sticker Missing (NYS')
# Ticket(summond_num=8523013120, plate_id='HPN9774', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 6), violation_code=74, vehicle_body_type='4DSD', maker='CHEVR', violation_descr='74-Missing Display Plate')
# Ticket(summond_num=7008336767, plate_id='HWL4734', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 1, 14), violation_code=74, vehicle_body_type='4DSD', maker='CHEVR', violation_descr='74A-Improperly Displayed Plate')
# Ticket(summond_num=8397514636, plate_id='FYW3850', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 22), violation_code=74, vehicle_body_type='SUBN', maker='FORD', violation_descr='74A-Improperly Displayed Plate')
# Ticket(summond_num=8528912840, plate_id='HNY5206', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 21), violation_code=74, vehicle_body_type='SUBN', maker='GMC', violation_descr='74A-Improperly Displayed Plate')
# Ticket(summond_num=8511501113, plate_id='FBP6836', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 16), violation_code=74, vehicle_body_type='SUBN', maker='HONDA', violation_descr='74-Missing Display Plate')
# Ticket(summond_num=8276551890, plate_id='HJR4081', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=74, vehicle_body_type='SUBN', maker='HONDA', violation_descr='74A-Improperly Displayed Plate')
# Ticket(summond_num=8214550531, plate_id='HJY2207', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 9), violation_code=74, vehicle_body_type='4DSD', maker='HYUND', violation_descr='74-Missing Display Plate')
# Ticket(summond_num=8487469012, plate_id='27527ME', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 27), violation_code=74, vehicle_body_type='DELV', maker='INTER', violation_descr='74-Missing Display Plate')
# Ticket(summond_num=8034780236, plate_id='HCD3158', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 2), violation_code=74, vehicle_body_type='SUBN', maker='KIA', violation_descr='74A-Improperly Displayed Plate')
# Ticket(summond_num=8545052455, plate_id='HMK1149', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 7), violation_code=74, vehicle_body_type='4DSD', maker='ME/BE', violation_descr='74-Missing Display Plate')
# Ticket(summond_num=1411263467, plate_id='BLANKPLATE', reg_state='99', plate_type='999', issue_date=datetime.date(2017, 2, 13), violation_code=74, vehicle_body_type='SDN', maker='NISSA', violation_descr='')
# Ticket(summond_num=8540001550, plate_id='HLA4803', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 23), violation_code=74, vehicle_body_type='4DSD', maker='SAAB', violation_descr='74-Missing Display Plate')
# Ticket(summond_num=8556155431, plate_id='HFB9919', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 26), violation_code=75, vehicle_body_type='4DSD', maker='DODGE', violation_descr='75-No Match-Plate/Reg. Sticker')
# Ticket(summond_num=8394016790, plate_id='31690BB', reg_state='NY', plate_type='OMR', issue_date=datetime.date(2016, 9, 6), violation_code=77, vehicle_body_type='BUS', maker='AM/T', violation_descr='77-Parked Bus (exc desig area)')
# Ticket(summond_num=1419472306, plate_id='56090BA', reg_state='NY', plate_type='OMR', issue_date=datetime.date(2017, 2, 20), violation_code=77, vehicle_body_type='BUS', maker='INTER', violation_descr='')
# Ticket(summond_num=8363508688, plate_id='97256', reg_state='MA', plate_type='APP', issue_date=datetime.date(2016, 8, 13), violation_code=77, vehicle_body_type='BUS', maker='NS/OT', violation_descr='77-Parked Bus (exc desig area)')
# Ticket(summond_num=1407740258, plate_id='2513JMG', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 11), violation_code=78, vehicle_body_type='DELV', maker='FRUEH', violation_descr='')
# Ticket(summond_num=8081047670, plate_id='AG84195', reg_state='AZ', plate_type='PAS', issue_date=datetime.date(2016, 9, 1), violation_code=78, vehicle_body_type='DELV', maker='GMC', violation_descr='78-Nighttime PKG on Res Street')
# Ticket(summond_num=8357010039, plate_id='ZBK5659', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2016, 9, 16), violation_code=78, vehicle_body_type='FLAT', maker='NS/OT', violation_descr='78-Nighttime PKG on Res Street')
# Ticket(summond_num=1408164401, plate_id='GCP8663', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 30), violation_code=80, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='')
# Ticket(summond_num=7065087220, plate_id='35989MJ', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 8, 28), violation_code=82, vehicle_body_type='VAN', maker='CHEVR', violation_descr='82-Unaltered Commerc Vehicle')
# Ticket(summond_num=8472028628, plate_id='80921MH', reg_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 30), violation_code=82, vehicle_body_type='VAN', maker='CHEVR', violation_descr='82-Unaltered Commerc Vehicle')
# Ticket(summond_num=8413507250, plate_id='XCGT11', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 18), violation_code=82, vehicle_body_type='PICK', maker='CHEVR', violation_descr='82-Unaltered Commerc Vehicle')
# Ticket(summond_num=8498413898, plate_id='2028133', reg_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 5, 24), violation_code=84, vehicle_body_type='DELV', maker='FRUEH', violation_descr='84-Platform lifts in low posit')
# Ticket(summond_num=8484405837, plate_id='2028134', reg_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 2, 15), violation_code=84, vehicle_body_type='DELV', maker='FRUEH', violation_descr='84-Platform lifts in low posit')
# Ticket(summond_num=8040125108, plate_id='AT985A', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 8, 29), violation_code=84, vehicle_body_type='DELV', maker='FRUEH', violation_descr='84-Platform lifts in low posit')
# Ticket(summond_num=8521821979, plate_id='XJX4470', reg_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 5, 18), violation_code=84, vehicle_body_type='TR/C', maker='FRUEH', violation_descr='84-Platform lifts in low posit')
# Ticket(summond_num=7662741072, plate_id='XY237D', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 8, 9), violation_code=84, vehicle_body_type='DELV', maker='HINO', violation_descr='84-Platform lifts in low posit')
# Ticket(summond_num=8529157072, plate_id='2380604', reg_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 3, 29), violation_code=84, vehicle_body_type='DELV', maker='INTER', violation_descr='84-Platform lifts in low posit')
# Ticket(summond_num=8354508808, plate_id='21239MG', reg_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 9), violation_code=84, vehicle_body_type='DELV', maker='MI/F', violation_descr='84-Platform lifts in low posit')
# Ticket(summond_num=1414702700, plate_id='AT785J', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 11, 27), violation_code=85, vehicle_body_type='TRAC', maker='FRUEH', violation_descr='')
# Ticket(summond_num=8466533837, plate_id='XANK50', reg_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 29), violation_code=85, vehicle_body_type='DELV', maker='HIN', violation_descr='85-Storage-3 hour Commercial')
# Ticket(summond_num=8525168063, plate_id='HBN8474', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 30), violation_code=91, vehicle_body_type='SUBN', maker='HONDA', violation_descr='91-Veh for Sale (Dealer Only)')
# Ticket(summond_num=1420730010, plate_id='GFW3620', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 10), violation_code=98, vehicle_body_type='SUBN', maker='CHEVR', violation_descr='')
# Ticket(summond_num=1414049870, plate_id='EJS4309', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 5), violation_code=98, vehicle_body_type='SDN', maker='NISSA', violation_descr='')
# Ticket(summond_num=1420795430, plate_id='HBS5720', reg_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 18), violation_code=98, vehicle_body_type='SDN', maker='NISSA', violation_descr='')

# %% [markdown]
# ## Goal 2
#
# Calculate the number of violations by car make.

# %%
tickets = Tickets(data)
viol_counter = {}
for t in tickets:
    if t.maker not in viol_counter:
        viol_counter[t.maker] = 1
    else:
        viol_counter[t.maker] += 1

# %%
print(viol_counter)
# Out:
# {'BMW': 34, 'CHEVR': 76, 'DODGE': 45, 'FORD': 104, 'FRUEH': 44, 'HONDA': 106, 'LINCO': 12, 'TOYOT': 112, 'CADIL': 9, 'CHRYS': 12, 'FIR': 1, 'GMC': 35, 'HYUND': 35, 'JAGUA': 3, 'JEEP': 22, 'LEXUS': 26, 'ME/BE': 38, 'MERCU': 4, 'MITSU': 11, 'NISSA': 70, 'HIN': 6, 'NS/OT': 18, 'WORKH': 2, 'ACURA': 12, 'AUDI': 12, 'INTER': 25, 'ISUZU': 10, 'KENWO': 5, 'KIA': 8, 'OLDSM': 1, 'SUBAR': 18, 'VOLVO': 12, 'SATUR': 2, 'SMART': 3, 'INFIN': 13, 'PETER': 1, '': 5, 'CITRO': 1, 'ROVER': 5, 'BUICK': 5, 'GEO': 1, 'MAZDA': 5, 'PORSC': 3, 'VOLKS': 8, 'YAMAH': 1, 'BSA': 1, 'MINI': 1, 'PONTI': 1, 'SPRI': 1, 'PLYMO': 1, 'SCION': 2, 'UPS': 1, 'FIAT': 1, 'UD': 1, 'UTILI': 1, 'GMCQ': 1, 'SAAB': 2, 'HINO': 2, 'STAR': 1, 'AM/T': 1, 'MI/F': 1}
